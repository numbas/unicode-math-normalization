# %%
import json
import sys
import unicodedata
from collections import defaultdict
from pathlib import Path

output_dir = Path('final_data')
output_dir.mkdir(exist_ok=True)

tmp_dir = Path('tmp')
tmp_dir.mkdir(exist_ok=True)

# %%
from IPython.display import HTML, display

def table(fn):
    h = '<div style="max-height: 15em; overflow-y:auto"><table>'
    for row in fn():
        h += '<tr>'+''.join(f'<td>{v}</td>' for v in row)+'</tr>'
    h += '</table></div>'
    
    display(HTML(h))
    
    return fn
    
def tsv_symbols(filename):
    def wrapper(fn):
        with open(filename,'w') as f:
            for row in fn():
                f.write('\t'.join(str(x) for x in row)+'\n')

    return wrapper

# %% [markdown]
# # Enumerate Unicode characters
#
# Enumerate all characters in Unicode, and then pick out subsets corresponding to mathematical letters and symbols, Greek letters, and subscript and superscript characters.

# %%
def valid_unicode(c):
    try:
        unicodedata.name(c)
        return True
    except ValueError:
        return False

all_unicode = [chr(i) for i in range(sys.maxunicode + 1) if valid_unicode(chr(i))]

# %%
math = [c for c in all_unicode if 'MATH' in unicodedata.name(c) or unicodedata.category(c) == 'Sm']

unicode_category = defaultdict(list)

for c in all_unicode:
    unicode_category[unicodedata.category(c)].append(c)

# %% [markdown]
# Characters already understood by Numbas JME:

# %%
categories = 'Ll,Lu,Lo,Lt,Nl,Nd,White_space'.split(',')
characters = r""" '".{}?/\n:&;|^>=<-+*#!(),[] """

# %% [markdown]
# # Create letter mappings
#
# For all mathematical letters, work out which Latin letter they correspond to, and extract any annotations from the unicodedata name.

# %%
import re
classes = set()
rest = []

letter_mapping = {}
for c in math:
    name = unicodedata.name(c)
    if unicodedata.category(c)[0] != 'L':
        continue
    m = re.match(r'^MATHEMATICAL (.*?) ?(NABLA|PARTIAL DIFFERENTIAL|(CAPITAL|SMALL( FINAL| DOTLESS)?) \w+|(CAPITAL )?\w+ SYMBOL)?$', name)
    m2 = re.match(r'^ARABIC MATHEMATICAL(?: (.*))? (\w+)', name)
    n = unicodedata.normalize('NFKD',c)
    if m:
        words = m.group(1).split(' ')
        classes = classes.union(set(words))
        letter_mapping[c] = (n, words)
    elif m2:
        words = m2.group(1).split(' ') if m2.group(1) else []
        classes = classes.union(set(words))
        letter_mapping[c] = (n,words)
    else:
        rest.append(name)

print(f'Unclassified letters: ', rest)

with open('other-letters.tsv') as f:
    lines = [l.split('\t') for l in f.read().strip().split('\n')]
    for line in lines:
        annotations = [w for w in line[7].split(' ') if w] if len(line)>=8 else []
        classes = classes.union(set(annotations))
        letter_mapping[line[1]] = [line[6], annotations]
        
print('Annotation words:')
for cc in sorted(classes):
    print(cc)
    
with open(output_dir / 'letters.json', 'w') as f:
    json.dump(letter_mapping, f, indent=4)
# Out:
# Unclassified letters:  []
# Annotation words:
# BLACK-LETTER
# BOLD
# DOTLESS
# DOUBLE-STRUCK
# FRAKTUR
# INITIAL
# ITALIC
# LOOPED
# MONOSPACE
# RING
# SANS-SERIF
# SCRIPT
# STRETCHED
# TAILED

# %%
unicodedata.category('∅')
# Out:
# 'Sm'

# %% [markdown]
# # Greek letters
#
# Mathematical Greek letters are dealt with above, but standard Greek letters should map to their names in Latin, e.g. α to 'alpha'.
#
# There are many combinations of Greek letters with diacritics, but these are normalized to multi-character strings, and not usually used in maths, so should be treated the same as other accented characters such as ü.

# %%
greek = [c for c in all_unicode if 'GREEK' in unicodedata.name(c)]

normalized_greek = sorted(set(unicodedata.normalize('NFKD',c)[0] for c in greek), key=lambda c: unicodedata.name(c))

@table
def greek_things():
    for c in greek:
        yield [c, unicodedata.name(c)]
# Out:
# <div style="max-height: 15em; overflow-y:auto"><table><tr><td>͂</td><td>COMBINING GREEK PERISPOMENI</td></tr><tr><td>̓</td><td>COMBINING GREEK KORONIS</td></tr><tr><td>̈́</td><td>COMBINING GREEK DIALYTIKA TONOS</td></tr><tr><td>ͅ</td><td>COMBINING GREEK YPOGEGRAMMENI</td></tr><tr><td>Ͱ</td><td>GREEK CAPITAL LETTER HETA</td></tr><tr><td>ͱ</td><td>GREEK SMALL LETTER HETA</td></tr><tr><td>Ͳ</td><td>GREEK CAPITAL LETTER ARCHAIC SAMPI</td></tr><tr><td>ͳ</td><td>GREEK SMALL LETTER ARCHAIC SAMPI</td></tr><tr><td>ʹ</td><td>GREEK NUMERAL SIGN</td></tr><tr><td>͵</td><td>GREEK LOWER NUMERAL SIGN</td></tr><tr><td>Ͷ</td><td>GREEK CAPITAL LETTER PAMPHYLIAN DIGAMMA</td></tr><tr><td>ͷ</td><td>GREEK SMALL LETTER PAMPHYLIAN DIGAMMA</td></tr><tr><td>ͺ</td><td>GREEK YPOGEGRAMMENI</td></tr><tr><td>ͻ</td><td>GREEK SMALL REVERSED LUNATE SIGMA SYMBOL</td></tr><tr><td>ͼ</td><td>GREEK SMALL DOTTED LUNATE SIGMA SYMBOL</td></tr><tr><td>ͽ</td><td>GREEK SMALL REVERSED DOTTED LUNATE SIGMA SYMBOL</td></tr><tr><td>;</td><td>GREEK QUESTION MARK</td></tr><tr><td>Ϳ</td><td>GREEK CAPITAL LETTER YOT</td></tr><tr><td>΄</td><td>GREEK TONOS</td></tr><tr><td>΅</td><td>GREEK DIALYTIKA TONOS</td></tr><tr><td>Ά</td><td>GREEK CAPITAL LETTER ALPHA WITH TONOS</td></tr><tr><td>·</td><td>GREEK ANO TELEIA</td></tr><tr><td>Έ</td><td>GREEK CAPITAL LETTER EPSILON WITH TONOS</td></tr><tr><td>Ή</td><td>GREEK CAPITAL LETTER ETA WITH TONOS</td></tr><tr><td>Ί</td><td>GREEK CAPITAL LETTER IOTA WITH TONOS</td></tr><tr><td>Ό</td><td>GREEK CAPITAL LETTER OMICRON WITH TONOS</td></tr><tr><td>Ύ</td><td>GREEK CAPITAL LETTER UPSILON WITH TONOS</td></tr><tr><td>Ώ</td><td>GREEK CAPITAL LETTER OMEGA WITH TONOS</td></tr><tr><td>ΐ</td><td>GREEK SMALL LETTER IOTA WITH DIALYTIKA AND TONOS</td></tr><tr><td>Α</td><td>GREEK CAPITAL LETTER ALPHA</td></tr><tr><td>Β</td><td>GREEK CAPITAL LETTER BETA</td></tr><tr><td>Γ</td><td>GREEK CAPITAL LETTER GAMMA</td></tr><tr><td>Δ</td><td>GREEK CAPITAL LETTER DELTA</td></tr><tr><td>Ε</td><td>GREEK CAPITAL LETTER EPSILON</td></tr><tr><td>Ζ</td><td>GREEK CAPITAL LETTER ZETA</td></tr><tr><td>Η</td><td>GREEK CAPITAL LETTER ETA</td></tr><tr><td>Θ</td><td>GREEK CAPITAL LETTER THETA</td></tr><tr><td>Ι</td><td>GREEK CAPITAL LETTER IOTA</td></tr><tr><td>Κ</td><td>GREEK CAPITAL LETTER KAPPA</td></tr><tr><td>Λ</td><td>GREEK CAPITAL LETTER LAMDA</td></tr><tr><td>Μ</td><td>GREEK CAPITAL LETTER MU</td></tr><tr><td>Ν</td><td>GREEK CAPITAL LETTER NU</td></tr><tr><td>Ξ</td><td>GREEK CAPITAL LETTER XI</td></tr><tr><td>Ο</td><td>GREEK CAPITAL LETTER OMICRON</td></tr><tr><td>Π</td><td>GREEK CAPITAL LETTER PI</td></tr><tr><td>Ρ</td><td>GREEK CAPITAL LETTER RHO</td></tr><tr><td>Σ</td><td>GREEK CAPITAL LETTER SIGMA</td></tr><tr><td>Τ</td><td>GREEK CAPITAL LETTER TAU</td></tr><tr><td>Υ</td><td>GREEK CAPITAL LETTER UPSILON</td></tr><tr><td>Φ</td><td>GREEK CAPITAL LETTER PHI</td></tr><tr><td>Χ</td><td>GREEK CAPITAL LETTER CHI</td></tr><tr><td>Ψ</td><td>GREEK CAPITAL LETTER PSI</td></tr><tr><td>Ω</td><td>GREEK CAPITAL LETTER OMEGA</td></tr><tr><td>Ϊ</td><td>GREEK CAPITAL LETTER IOTA WITH DIALYTIKA</td></tr><tr><td>Ϋ</td><td>GREEK CAPITAL LETTER UPSILON WITH DIALYTIKA</td></tr><tr><td>ά</td><td>GREEK SMALL LETTER ALPHA WITH TONOS</td></tr><tr><td>έ</td><td>GREEK SMALL LETTER EPSILON WITH TONOS</td></tr><tr><td>ή</td><td>GREEK SMALL LETTER ETA WITH TONOS</td></tr><tr><td>ί</td><td>GREEK SMALL LETTER IOTA WITH TONOS</td></tr><tr><td>ΰ</td><td>GREEK SMALL LETTER UPSILON WITH DIALYTIKA AND TONOS</td></tr><tr><td>α</td><td>GREEK SMALL LETTER ALPHA</td></tr><tr><td>β</td><td>GREEK SMALL LETTER BETA</td></tr><tr><td>γ</td><td>GREEK SMALL LETTER GAMMA</td></tr><tr><td>δ</td><td>GREEK SMALL LETTER DELTA</td></tr><tr><td>ε</td><td>GREEK SMALL LETTER EPSILON</td></tr><tr><td>ζ</td><td>GREEK SMALL LETTER ZETA</td></tr><tr><td>η</td><td>GREEK SMALL LETTER ETA</td></tr><tr><td>θ</td><td>GREEK SMALL LETTER THETA</td></tr><tr><td>ι</td><td>GREEK SMALL LETTER IOTA</td></tr><tr><td>κ</td><td>GREEK SMALL LETTER K ...

# %%
with open('greek.tsv') as f:
    lines = [l.split('\t') for l in f.read().strip().split('\n')]
    greek_mapping = {k:[v,[]] for k,v in lines}
    
with open(output_dir / 'greek.json', 'w') as f:
    json.dump(greek_mapping, f, indent=4)

# %% [markdown]
# # Symbol mappings
#
# There are hundreds of characters in the "Mathematical symbols" category.
# Lots of them are combinations of symbols that would be very hard to disentangle, while others correspond to operations that we're extremely unlikely to see in e-assessment.
#
# So the best method I can think of for coming up with a mapping to common function names or operator symbols is to go through the list manually, removing rare combinations or operations.

# %%
unicodedata.name('⟹')
# Out:
# 'LONG RIGHTWARDS DOUBLE ARROW'

# %%
@tsv_symbols(tmp_dir / 'unedited-symbols.tsv')
@table
def symbols_to_map():
    for c in math+['ˆ']:
        if c in letter_mapping:
            continue
        category = unicodedata.category(c)
        if category == 'Nd':
            continue
        n = unicodedata.normalize('NFKC',c)
        if not (category in categories or c in characters or n in characters):
            yield (c, unicodedata.name(c), n, unicodedata.name(n[0]),len(n))
# Out:
# <div style="max-height: 15em; overflow-y:auto"><table><tr><td>~</td><td>TILDE</td><td>~</td><td>TILDE</td><td>1</td></tr><tr><td>¬</td><td>NOT SIGN</td><td>¬</td><td>NOT SIGN</td><td>1</td></tr><tr><td>±</td><td>PLUS-MINUS SIGN</td><td>±</td><td>PLUS-MINUS SIGN</td><td>1</td></tr><tr><td>×</td><td>MULTIPLICATION SIGN</td><td>×</td><td>MULTIPLICATION SIGN</td><td>1</td></tr><tr><td>÷</td><td>DIVISION SIGN</td><td>÷</td><td>DIVISION SIGN</td><td>1</td></tr><tr><td>϶</td><td>GREEK REVERSED LUNATE EPSILON SYMBOL</td><td>϶</td><td>GREEK REVERSED LUNATE EPSILON SYMBOL</td><td>1</td></tr><tr><td>؆</td><td>ARABIC-INDIC CUBE ROOT</td><td>؆</td><td>ARABIC-INDIC CUBE ROOT</td><td>1</td></tr><tr><td>؇</td><td>ARABIC-INDIC FOURTH ROOT</td><td>؇</td><td>ARABIC-INDIC FOURTH ROOT</td><td>1</td></tr><tr><td>؈</td><td>ARABIC RAY</td><td>؈</td><td>ARABIC RAY</td><td>1</td></tr><tr><td>⁄</td><td>FRACTION SLASH</td><td>⁄</td><td>FRACTION SLASH</td><td>1</td></tr><tr><td>⁒</td><td>COMMERCIAL MINUS SIGN</td><td>⁒</td><td>COMMERCIAL MINUS SIGN</td><td>1</td></tr><tr><td>⁻</td><td>SUPERSCRIPT MINUS</td><td>−</td><td>MINUS SIGN</td><td>1</td></tr><tr><td>₋</td><td>SUBSCRIPT MINUS</td><td>−</td><td>MINUS SIGN</td><td>1</td></tr><tr><td>℘</td><td>SCRIPT CAPITAL P</td><td>℘</td><td>SCRIPT CAPITAL P</td><td>1</td></tr><tr><td>⅀</td><td>DOUBLE-STRUCK N-ARY SUMMATION</td><td>∑</td><td>N-ARY SUMMATION</td><td>1</td></tr><tr><td>⅁</td><td>TURNED SANS-SERIF CAPITAL G</td><td>⅁</td><td>TURNED SANS-SERIF CAPITAL G</td><td>1</td></tr><tr><td>⅂</td><td>TURNED SANS-SERIF CAPITAL L</td><td>⅂</td><td>TURNED SANS-SERIF CAPITAL L</td><td>1</td></tr><tr><td>⅃</td><td>REVERSED SANS-SERIF CAPITAL L</td><td>⅃</td><td>REVERSED SANS-SERIF CAPITAL L</td><td>1</td></tr><tr><td>⅄</td><td>TURNED SANS-SERIF CAPITAL Y</td><td>⅄</td><td>TURNED SANS-SERIF CAPITAL Y</td><td>1</td></tr><tr><td>⅋</td><td>TURNED AMPERSAND</td><td>⅋</td><td>TURNED AMPERSAND</td><td>1</td></tr><tr><td>←</td><td>LEFTWARDS ARROW</td><td>←</td><td>LEFTWARDS ARROW</td><td>1</td></tr><tr><td>↑</td><td>UPWARDS ARROW</td><td>↑</td><td>UPWARDS ARROW</td><td>1</td></tr><tr><td>→</td><td>RIGHTWARDS ARROW</td><td>→</td><td>RIGHTWARDS ARROW</td><td>1</td></tr><tr><td>↓</td><td>DOWNWARDS ARROW</td><td>↓</td><td>DOWNWARDS ARROW</td><td>1</td></tr><tr><td>↔</td><td>LEFT RIGHT ARROW</td><td>↔</td><td>LEFT RIGHT ARROW</td><td>1</td></tr><tr><td>↚</td><td>LEFTWARDS ARROW WITH STROKE</td><td>↚</td><td>LEFTWARDS ARROW WITH STROKE</td><td>1</td></tr><tr><td>↛</td><td>RIGHTWARDS ARROW WITH STROKE</td><td>↛</td><td>RIGHTWARDS ARROW WITH STROKE</td><td>1</td></tr><tr><td>↠</td><td>RIGHTWARDS TWO HEADED ARROW</td><td>↠</td><td>RIGHTWARDS TWO HEADED ARROW</td><td>1</td></tr><tr><td>↣</td><td>RIGHTWARDS ARROW WITH TAIL</td><td>↣</td><td>RIGHTWARDS ARROW WITH TAIL</td><td>1</td></tr><tr><td>↦</td><td>RIGHTWARDS ARROW FROM BAR</td><td>↦</td><td>RIGHTWARDS ARROW FROM BAR</td><td>1</td></tr><tr><td>↮</td><td>LEFT RIGHT ARROW WITH STROKE</td><td>↮</td><td>LEFT RIGHT ARROW WITH STROKE</td><td>1</td></tr><tr><td>⇎</td><td>LEFT RIGHT DOUBLE ARROW WITH STROKE</td><td>⇎</td><td>LEFT RIGHT DOUBLE ARROW WITH STROKE</td><td>1</td></tr><tr><td>⇏</td><td>RIGHTWARDS DOUBLE ARROW WITH STROKE</td><td>⇏</td><td>RIGHTWARDS DOUBLE ARROW WITH STROKE</td><td>1</td></tr><tr><td>⇒</td><td>RIGHTWARDS DOUBLE ARROW</td><td>⇒</td><td>RIGHTWARDS DOUBLE ARROW</td><td>1</td></tr><tr><td>⇔</td><td>LEFT RIGHT DOUBLE ARROW</td><td>⇔</td><td>LEFT RIGHT DOUBLE ARROW</td><td>1</td></tr><tr><td>⇴</td><td>RIGHT ARROW WITH SMALL CIRCLE</td><td>⇴</td><td>RIGHT ARROW WITH SMALL CIRCLE</td><td>1</td></tr><tr><td>⇵</td><td>DOWNWARDS ARROW LEFTWARDS OF UPWARDS ARROW</td><td>⇵</td><td>DOWNWARDS ARROW LEFTWARDS OF UPWARDS ARROW</td><td>1</td></tr><tr><td>⇶</td><td>THREE RIGHTWARDS ARROWS</td><td>⇶</td><td>THREE RIGHTWARDS ARROWS</td><td>1</td></tr><tr><td>⇷</td><td>LEFTWARDS ARROW WITH VERTICAL STROKE</td><td>⇷</td><td>LEFTWARDS ARROW WITH VERTICAL STROKE</td><td>1</td></tr><tr>< ...

# %% [markdown]
# Copy `tmp/unedited-symbols.tsv` to `symbols.tsv`, remove characters we won't deal with, and give mappings for what remains.

# %%
symbol_mapping = {}

with open('symbols.tsv') as f:
    for row in f.read().strip().split('\n'):
        bits = row.split('\t')
        c = bits[0]
        alias = bits[5]
        annotations = bits[6].split(' ') if len(bits)>=7 else []
        symbol_mapping[c] = [alias, annotations]
 
with open(output_dir / 'symbols.json','w') as f:
    json.dump(symbol_mapping, f, indent=4)

# %% [markdown]
# Show symbols that are not explicitly mapped, and aren't in the existing JME grammar:

# %%
@table
def not_explicitly_mapped():
    for c in math:
        if c in letter_mapping or c in symbol_mapping:
            continue
        n = unicodedata.normalize('NFKC',c)
        if n[0] not in characters:
            yield [c,unicodedata.name(c),n,unicodedata.name(n[0]),len(n)]
# Out:
# <div style="max-height: 15em; overflow-y:auto"><table><tr><td>϶</td><td>GREEK REVERSED LUNATE EPSILON SYMBOL</td><td>϶</td><td>GREEK REVERSED LUNATE EPSILON SYMBOL</td><td>1</td></tr><tr><td>؈</td><td>ARABIC RAY</td><td>؈</td><td>ARABIC RAY</td><td>1</td></tr><tr><td>⁻</td><td>SUPERSCRIPT MINUS</td><td>−</td><td>MINUS SIGN</td><td>1</td></tr><tr><td>⅁</td><td>TURNED SANS-SERIF CAPITAL G</td><td>⅁</td><td>TURNED SANS-SERIF CAPITAL G</td><td>1</td></tr><tr><td>⅂</td><td>TURNED SANS-SERIF CAPITAL L</td><td>⅂</td><td>TURNED SANS-SERIF CAPITAL L</td><td>1</td></tr><tr><td>⅃</td><td>REVERSED SANS-SERIF CAPITAL L</td><td>⅃</td><td>REVERSED SANS-SERIF CAPITAL L</td><td>1</td></tr><tr><td>⅄</td><td>TURNED SANS-SERIF CAPITAL Y</td><td>⅄</td><td>TURNED SANS-SERIF CAPITAL Y</td><td>1</td></tr><tr><td>⅋</td><td>TURNED AMPERSAND</td><td>⅋</td><td>TURNED AMPERSAND</td><td>1</td></tr><tr><td>←</td><td>LEFTWARDS ARROW</td><td>←</td><td>LEFTWARDS ARROW</td><td>1</td></tr><tr><td>↑</td><td>UPWARDS ARROW</td><td>↑</td><td>UPWARDS ARROW</td><td>1</td></tr><tr><td>→</td><td>RIGHTWARDS ARROW</td><td>→</td><td>RIGHTWARDS ARROW</td><td>1</td></tr><tr><td>↓</td><td>DOWNWARDS ARROW</td><td>↓</td><td>DOWNWARDS ARROW</td><td>1</td></tr><tr><td>↔</td><td>LEFT RIGHT ARROW</td><td>↔</td><td>LEFT RIGHT ARROW</td><td>1</td></tr><tr><td>↚</td><td>LEFTWARDS ARROW WITH STROKE</td><td>↚</td><td>LEFTWARDS ARROW WITH STROKE</td><td>1</td></tr><tr><td>↛</td><td>RIGHTWARDS ARROW WITH STROKE</td><td>↛</td><td>RIGHTWARDS ARROW WITH STROKE</td><td>1</td></tr><tr><td>↠</td><td>RIGHTWARDS TWO HEADED ARROW</td><td>↠</td><td>RIGHTWARDS TWO HEADED ARROW</td><td>1</td></tr><tr><td>↣</td><td>RIGHTWARDS ARROW WITH TAIL</td><td>↣</td><td>RIGHTWARDS ARROW WITH TAIL</td><td>1</td></tr><tr><td>↦</td><td>RIGHTWARDS ARROW FROM BAR</td><td>↦</td><td>RIGHTWARDS ARROW FROM BAR</td><td>1</td></tr><tr><td>↮</td><td>LEFT RIGHT ARROW WITH STROKE</td><td>↮</td><td>LEFT RIGHT ARROW WITH STROKE</td><td>1</td></tr><tr><td>⇎</td><td>LEFT RIGHT DOUBLE ARROW WITH STROKE</td><td>⇎</td><td>LEFT RIGHT DOUBLE ARROW WITH STROKE</td><td>1</td></tr><tr><td>⇏</td><td>RIGHTWARDS DOUBLE ARROW WITH STROKE</td><td>⇏</td><td>RIGHTWARDS DOUBLE ARROW WITH STROKE</td><td>1</td></tr><tr><td>⇒</td><td>RIGHTWARDS DOUBLE ARROW</td><td>⇒</td><td>RIGHTWARDS DOUBLE ARROW</td><td>1</td></tr><tr><td>⇔</td><td>LEFT RIGHT DOUBLE ARROW</td><td>⇔</td><td>LEFT RIGHT DOUBLE ARROW</td><td>1</td></tr><tr><td>⇴</td><td>RIGHT ARROW WITH SMALL CIRCLE</td><td>⇴</td><td>RIGHT ARROW WITH SMALL CIRCLE</td><td>1</td></tr><tr><td>⇵</td><td>DOWNWARDS ARROW LEFTWARDS OF UPWARDS ARROW</td><td>⇵</td><td>DOWNWARDS ARROW LEFTWARDS OF UPWARDS ARROW</td><td>1</td></tr><tr><td>⇶</td><td>THREE RIGHTWARDS ARROWS</td><td>⇶</td><td>THREE RIGHTWARDS ARROWS</td><td>1</td></tr><tr><td>⇷</td><td>LEFTWARDS ARROW WITH VERTICAL STROKE</td><td>⇷</td><td>LEFTWARDS ARROW WITH VERTICAL STROKE</td><td>1</td></tr><tr><td>⇸</td><td>RIGHTWARDS ARROW WITH VERTICAL STROKE</td><td>⇸</td><td>RIGHTWARDS ARROW WITH VERTICAL STROKE</td><td>1</td></tr><tr><td>⇹</td><td>LEFT RIGHT ARROW WITH VERTICAL STROKE</td><td>⇹</td><td>LEFT RIGHT ARROW WITH VERTICAL STROKE</td><td>1</td></tr><tr><td>⇺</td><td>LEFTWARDS ARROW WITH DOUBLE VERTICAL STROKE</td><td>⇺</td><td>LEFTWARDS ARROW WITH DOUBLE VERTICAL STROKE</td><td>1</td></tr><tr><td>⇻</td><td>RIGHTWARDS ARROW WITH DOUBLE VERTICAL STROKE</td><td>⇻</td><td>RIGHTWARDS ARROW WITH DOUBLE VERTICAL STROKE</td><td>1</td></tr><tr><td>⇼</td><td>LEFT RIGHT ARROW WITH DOUBLE VERTICAL STROKE</td><td>⇼</td><td>LEFT RIGHT ARROW WITH DOUBLE VERTICAL STROKE</td><td>1</td></tr><tr><td>⇽</td><td>LEFTWARDS OPEN-HEADED ARROW</td><td>⇽</td><td>LEFTWARDS OPEN-HEADED ARROW</td><td>1</td></tr><tr><td>⇾</td><td>RIGHTWARDS OPEN-HEADED ARROW</td><td>⇾</td><td>RIGHTWARDS OPEN-HEADED ARROW</td><td>1</td></tr><tr><td>⇿</td><td>LEFT RIGHT OPEN-HEADED ARROW</td><td>⇿</td><td>LEFT RIGHT OPEN-HEADED ARROW</td><td>1</td></tr><tr><td>∎</td><td>END OF PROOF</td><td>∎ ...

# %% [markdown]
# # Punctuation characters
#
# There are lots and lots of punctuation characters. Of particular interest are the brackets and parentheses.
# It looks like we can rely on the standard normalization algorithm to convert these to the most common characters, so we don't need to produce a manual mapping dictionary.
#
# Any character in category `Po` which doesn't match another kind of token should be treated as a punctuation token, and normalized.
#
# The cell below displays all punctuation symbols whose normalized versions are not in the existing JME grammar.

# %%
@table
def unrecognised_punctuation():
    for c in unicode_category['Po']:
        n = unicodedata.normalize('NFKD',c)
        if n not in characters:
            yield [c,n, unicodedata.name(c)]
# Out:
# <div style="max-height: 15em; overflow-y:auto"><table><tr><td>%</td><td>%</td><td>PERCENT SIGN</td></tr><tr><td>@</td><td>@</td><td>COMMERCIAL AT</td></tr><tr><td>¡</td><td>¡</td><td>INVERTED EXCLAMATION MARK</td></tr><tr><td>§</td><td>§</td><td>SECTION SIGN</td></tr><tr><td>¶</td><td>¶</td><td>PILCROW SIGN</td></tr><tr><td>·</td><td>·</td><td>MIDDLE DOT</td></tr><tr><td>¿</td><td>¿</td><td>INVERTED QUESTION MARK</td></tr><tr><td>·</td><td>·</td><td>GREEK ANO TELEIA</td></tr><tr><td>՚</td><td>՚</td><td>ARMENIAN APOSTROPHE</td></tr><tr><td>՛</td><td>՛</td><td>ARMENIAN EMPHASIS MARK</td></tr><tr><td>՜</td><td>՜</td><td>ARMENIAN EXCLAMATION MARK</td></tr><tr><td>՝</td><td>՝</td><td>ARMENIAN COMMA</td></tr><tr><td>՞</td><td>՞</td><td>ARMENIAN QUESTION MARK</td></tr><tr><td>՟</td><td>՟</td><td>ARMENIAN ABBREVIATION MARK</td></tr><tr><td>։</td><td>։</td><td>ARMENIAN FULL STOP</td></tr><tr><td>׀</td><td>׀</td><td>HEBREW PUNCTUATION PASEQ</td></tr><tr><td>׃</td><td>׃</td><td>HEBREW PUNCTUATION SOF PASUQ</td></tr><tr><td>׆</td><td>׆</td><td>HEBREW PUNCTUATION NUN HAFUKHA</td></tr><tr><td>׳</td><td>׳</td><td>HEBREW PUNCTUATION GERESH</td></tr><tr><td>״</td><td>״</td><td>HEBREW PUNCTUATION GERSHAYIM</td></tr><tr><td>؉</td><td>؉</td><td>ARABIC-INDIC PER MILLE SIGN</td></tr><tr><td>؊</td><td>؊</td><td>ARABIC-INDIC PER TEN THOUSAND SIGN</td></tr><tr><td>،</td><td>،</td><td>ARABIC COMMA</td></tr><tr><td>؍</td><td>؍</td><td>ARABIC DATE SEPARATOR</td></tr><tr><td>؛</td><td>؛</td><td>ARABIC SEMICOLON</td></tr><tr><td>؞</td><td>؞</td><td>ARABIC TRIPLE DOT PUNCTUATION MARK</td></tr><tr><td>؟</td><td>؟</td><td>ARABIC QUESTION MARK</td></tr><tr><td>٪</td><td>٪</td><td>ARABIC PERCENT SIGN</td></tr><tr><td>٫</td><td>٫</td><td>ARABIC DECIMAL SEPARATOR</td></tr><tr><td>٬</td><td>٬</td><td>ARABIC THOUSANDS SEPARATOR</td></tr><tr><td>٭</td><td>٭</td><td>ARABIC FIVE POINTED STAR</td></tr><tr><td>۔</td><td>۔</td><td>ARABIC FULL STOP</td></tr><tr><td>܀</td><td>܀</td><td>SYRIAC END OF PARAGRAPH</td></tr><tr><td>܁</td><td>܁</td><td>SYRIAC SUPRALINEAR FULL STOP</td></tr><tr><td>܂</td><td>܂</td><td>SYRIAC SUBLINEAR FULL STOP</td></tr><tr><td>܃</td><td>܃</td><td>SYRIAC SUPRALINEAR COLON</td></tr><tr><td>܄</td><td>܄</td><td>SYRIAC SUBLINEAR COLON</td></tr><tr><td>܅</td><td>܅</td><td>SYRIAC HORIZONTAL COLON</td></tr><tr><td>܆</td><td>܆</td><td>SYRIAC COLON SKEWED LEFT</td></tr><tr><td>܇</td><td>܇</td><td>SYRIAC COLON SKEWED RIGHT</td></tr><tr><td>܈</td><td>܈</td><td>SYRIAC SUPRALINEAR COLON SKEWED LEFT</td></tr><tr><td>܉</td><td>܉</td><td>SYRIAC SUBLINEAR COLON SKEWED RIGHT</td></tr><tr><td>܊</td><td>܊</td><td>SYRIAC CONTRACTION</td></tr><tr><td>܋</td><td>܋</td><td>SYRIAC HARKLEAN OBELUS</td></tr><tr><td>܌</td><td>܌</td><td>SYRIAC HARKLEAN METOBELUS</td></tr><tr><td>܍</td><td>܍</td><td>SYRIAC HARKLEAN ASTERISCUS</td></tr><tr><td>߷</td><td>߷</td><td>NKO SYMBOL GBAKURUNEN</td></tr><tr><td>߸</td><td>߸</td><td>NKO COMMA</td></tr><tr><td>߹</td><td>߹</td><td>NKO EXCLAMATION MARK</td></tr><tr><td>࠰</td><td>࠰</td><td>SAMARITAN PUNCTUATION NEQUDAA</td></tr><tr><td>࠱</td><td>࠱</td><td>SAMARITAN PUNCTUATION AFSAAQ</td></tr><tr><td>࠲</td><td>࠲</td><td>SAMARITAN PUNCTUATION ANGED</td></tr><tr><td>࠳</td><td>࠳</td><td>SAMARITAN PUNCTUATION BAU</td></tr><tr><td>࠴</td><td>࠴</td><td>SAMARITAN PUNCTUATION ATMAAU</td></tr><tr><td>࠵</td><td>࠵</td><td>SAMARITAN PUNCTUATION SHIYYAALAA</td></tr><tr><td>࠶</td><td>࠶</td><td>SAMARITAN ABBREVIATION MARK</td></tr><tr><td>࠷</td><td>࠷</td><td>SAMARITAN PUNCTUATION MELODIC QITSA</td></tr><tr><td>࠸</td><td>࠸</td><td>SAMARITAN PUNCTUATION ZIQAA</td></tr><tr><td>࠹</td><td>࠹</td><td>SAMARITAN PUNCTUATION QITSA</td></tr><tr><td>࠺</td><td>࠺</td><td>SAMARITAN PUNCTUATION ZAEF</td></tr><tr><td>࠻</td><td>࠻</td><td>SAMARITAN PUNCTUATION TURU</td></tr><tr><td>࠼</td><td>࠼</td><td>SAMARITAN PUNCTUATION ARKAANU</td></tr><tr><td>࠽</td><td>࠽</td><td>SAMARITAN PUNCTUATION SOF MASHFAAT</td></tr><tr><td>࠾</td><td>࠾</td><td>SAMARITAN PUNCTUATION ANNAAU</td></tr><tr ...

# %% [markdown]
# # Digits
#
# There are a few variations on the European digits that normalize to the ASCII digits.
#
# There are also a couple of sets of circled digits that don't normalize to anything else - should these be converted to ASCII digits too?
#
# Finally, there are lots of digits in other scripts. When these are used in a base-10 system and map directly on to the digits 0-9, they could be mapped, but there are a variety of other symbols representing fractions, such as "TELUGU FRACTION DIGIT ONE FOR EVEN POWERS OF FOUR". It's probably safest to ignore these and throw an error if they're used, or deal with them in a dedicated number notation style.
#
# So just normalize everything in class `Nd`.

# %%
digits = [c for c in all_unicode if unicodedata.category(c) =='Nd']

@table
def digits():
    for k, cs in sorted({k:[c for c in digits if unicodedata.normalize('NFKD',c)==k] for k in set(unicodedata.normalize('NFKD',c) for c in digits)}.items(), key=lambda x:(-len(x[1]),unicodedata.name(x[0][0])),reverse=False):
        names = ', '.join(unicodedata.name(c) for c in k)
        yield [k,len(k),names,cs]
# Out:
# <div style="max-height: 15em; overflow-y:auto"><table><tr><td>8</td><td>1</td><td>DIGIT EIGHT</td><td>['8', '８', '𝟖', '𝟠', '𝟪', '𝟴', '𝟾', '🯸']</td></tr><tr><td>5</td><td>1</td><td>DIGIT FIVE</td><td>['5', '５', '𝟓', '𝟝', '𝟧', '𝟱', '𝟻', '🯵']</td></tr><tr><td>4</td><td>1</td><td>DIGIT FOUR</td><td>['4', '４', '𝟒', '𝟜', '𝟦', '𝟰', '𝟺', '🯴']</td></tr><tr><td>9</td><td>1</td><td>DIGIT NINE</td><td>['9', '９', '𝟗', '𝟡', '𝟫', '𝟵', '𝟿', '🯹']</td></tr><tr><td>1</td><td>1</td><td>DIGIT ONE</td><td>['1', '１', '𝟏', '𝟙', '𝟣', '𝟭', '𝟷', '🯱']</td></tr><tr><td>7</td><td>1</td><td>DIGIT SEVEN</td><td>['7', '７', '𝟕', '𝟟', '𝟩', '𝟳', '𝟽', '🯷']</td></tr><tr><td>6</td><td>1</td><td>DIGIT SIX</td><td>['6', '６', '𝟔', '𝟞', '𝟨', '𝟲', '𝟼', '🯶']</td></tr><tr><td>3</td><td>1</td><td>DIGIT THREE</td><td>['3', '３', '𝟑', '𝟛', '𝟥', '𝟯', '𝟹', '🯳']</td></tr><tr><td>2</td><td>1</td><td>DIGIT TWO</td><td>['2', '２', '𝟐', '𝟚', '𝟤', '𝟮', '𝟸', '🯲']</td></tr><tr><td>0</td><td>1</td><td>DIGIT ZERO</td><td>['0', '０', '𝟎', '𝟘', '𝟢', '𝟬', '𝟶', '🯰']</td></tr><tr><td>𞥘</td><td>1</td><td>ADLAM DIGIT EIGHT</td><td>['𞥘']</td></tr><tr><td>𞥕</td><td>1</td><td>ADLAM DIGIT FIVE</td><td>['𞥕']</td></tr><tr><td>𞥔</td><td>1</td><td>ADLAM DIGIT FOUR</td><td>['𞥔']</td></tr><tr><td>𞥙</td><td>1</td><td>ADLAM DIGIT NINE</td><td>['𞥙']</td></tr><tr><td>𞥑</td><td>1</td><td>ADLAM DIGIT ONE</td><td>['𞥑']</td></tr><tr><td>𞥗</td><td>1</td><td>ADLAM DIGIT SEVEN</td><td>['𞥗']</td></tr><tr><td>𞥖</td><td>1</td><td>ADLAM DIGIT SIX</td><td>['𞥖']</td></tr><tr><td>𞥓</td><td>1</td><td>ADLAM DIGIT THREE</td><td>['𞥓']</td></tr><tr><td>𞥒</td><td>1</td><td>ADLAM DIGIT TWO</td><td>['𞥒']</td></tr><tr><td>𞥐</td><td>1</td><td>ADLAM DIGIT ZERO</td><td>['𞥐']</td></tr><tr><td>𑜸</td><td>1</td><td>AHOM DIGIT EIGHT</td><td>['𑜸']</td></tr><tr><td>𑜵</td><td>1</td><td>AHOM DIGIT FIVE</td><td>['𑜵']</td></tr><tr><td>𑜴</td><td>1</td><td>AHOM DIGIT FOUR</td><td>['𑜴']</td></tr><tr><td>𑜹</td><td>1</td><td>AHOM DIGIT NINE</td><td>['𑜹']</td></tr><tr><td>𑜱</td><td>1</td><td>AHOM DIGIT ONE</td><td>['𑜱']</td></tr><tr><td>𑜷</td><td>1</td><td>AHOM DIGIT SEVEN</td><td>['𑜷']</td></tr><tr><td>𑜶</td><td>1</td><td>AHOM DIGIT SIX</td><td>['𑜶']</td></tr><tr><td>𑜳</td><td>1</td><td>AHOM DIGIT THREE</td><td>['𑜳']</td></tr><tr><td>𑜲</td><td>1</td><td>AHOM DIGIT TWO</td><td>['𑜲']</td></tr><tr><td>𑜰</td><td>1</td><td>AHOM DIGIT ZERO</td><td>['𑜰']</td></tr><tr><td>٨</td><td>1</td><td>ARABIC-INDIC DIGIT EIGHT</td><td>['٨']</td></tr><tr><td>٥</td><td>1</td><td>ARABIC-INDIC DIGIT FIVE</td><td>['٥']</td></tr><tr><td>٤</td><td>1</td><td>ARABIC-INDIC DIGIT FOUR</td><td>['٤']</td></tr><tr><td>٩</td><td>1</td><td>ARABIC-INDIC DIGIT NINE</td><td>['٩']</td></tr><tr><td>١</td><td>1</td><td>ARABIC-INDIC DIGIT ONE</td><td>['١']</td></tr><tr><td>٧</td><td>1</td><td>ARABIC-INDIC DIGIT SEVEN</td><td>['٧']</td></tr><tr><td>٦</td><td>1</td><td>ARABIC-INDIC DIGIT SIX</td><td>['٦']</td></tr><tr><td>٣</td><td>1</td><td>ARABIC-INDIC DIGIT THREE</td><td>['٣']</td></tr><tr><td>٢</td><td>1</td><td>ARABIC-INDIC DIGIT TWO</td><td>['٢']</td></tr><tr><td>٠</td><td>1</td><td>ARABIC-INDIC DIGIT ZERO</td><td>['٠']</td></tr><tr><td>᭘</td><td>1</td><td>BALINESE DIGIT EIGHT</td><td>['᭘']</td></tr><tr><td>᭕</td><td>1</td><td>BALINESE DIGIT FIVE</td><td>['᭕']</td></tr><tr><td>᭔</td><td>1</td><td>BALINESE DIGIT FOUR</td><td>['᭔']</td></tr><tr><td>᭙</td><td>1</td><td>BALINESE DIGIT NINE</td><td>['᭙']</td></tr><tr><td>᭑</td><td>1</td><td>BALINESE DIGIT ONE</td><td>['᭑']</td></tr><tr><td>᭗</td><td>1</td><td>BALINESE DIGIT SEVEN</td><td>['᭗']</td></tr><tr><td>᭖</td><td>1</td><td>BALINESE DIGIT SIX</td><td>['᭖']</td></tr><tr><td>᭓</td><td>1</td><td>BALINESE DIGIT THREE</td><td>['᭓']</td></tr><tr><td>᭒</td><td>1</td><td>BALINESE DIGIT TWO</td><td>['᭒']</td></tr><tr><td>᭐</td><td>1</td><td>BALINESE DIGIT ZERO</td><td>['᭐']</td></tr><tr><td>৮</td><td>1</td><td>BENGALI DIGIT EIGHT</td><td>['৮']</td></tr><tr><td>৫</td><td>1</td><td>BENGALI DIGIT FIVE</td><td>['৫']</td></tr><tr><td>৪</td><td>1</td>< ...

# %% [markdown]
# Class `Nl` is "letter numbers", such as Roman numerals. These normalize to the corresponding letters.
# They should map to numbers, but they don't work the same way as the conventional base-10 system, so should be implemented as dedicated number notation styles, and throw an error if used otherwise.

# %%
numerals = [c for c in all_unicode if unicodedata.category(c) == 'Nl']

@table
def show_numerals():
    for c in numerals:
        n = unicodedata.normalize('NFKD',c)
        names = ', '.join(unicodedata.name(c) for c in n)
        yield [c, unicodedata.name(c), n, names]
# Out:
# <div style="max-height: 15em; overflow-y:auto"><table><tr><td>ᛮ</td><td>RUNIC ARLAUG SYMBOL</td><td>ᛮ</td><td>RUNIC ARLAUG SYMBOL</td></tr><tr><td>ᛯ</td><td>RUNIC TVIMADUR SYMBOL</td><td>ᛯ</td><td>RUNIC TVIMADUR SYMBOL</td></tr><tr><td>ᛰ</td><td>RUNIC BELGTHOR SYMBOL</td><td>ᛰ</td><td>RUNIC BELGTHOR SYMBOL</td></tr><tr><td>Ⅰ</td><td>ROMAN NUMERAL ONE</td><td>I</td><td>LATIN CAPITAL LETTER I</td></tr><tr><td>Ⅱ</td><td>ROMAN NUMERAL TWO</td><td>II</td><td>LATIN CAPITAL LETTER I, LATIN CAPITAL LETTER I</td></tr><tr><td>Ⅲ</td><td>ROMAN NUMERAL THREE</td><td>III</td><td>LATIN CAPITAL LETTER I, LATIN CAPITAL LETTER I, LATIN CAPITAL LETTER I</td></tr><tr><td>Ⅳ</td><td>ROMAN NUMERAL FOUR</td><td>IV</td><td>LATIN CAPITAL LETTER I, LATIN CAPITAL LETTER V</td></tr><tr><td>Ⅴ</td><td>ROMAN NUMERAL FIVE</td><td>V</td><td>LATIN CAPITAL LETTER V</td></tr><tr><td>Ⅵ</td><td>ROMAN NUMERAL SIX</td><td>VI</td><td>LATIN CAPITAL LETTER V, LATIN CAPITAL LETTER I</td></tr><tr><td>Ⅶ</td><td>ROMAN NUMERAL SEVEN</td><td>VII</td><td>LATIN CAPITAL LETTER V, LATIN CAPITAL LETTER I, LATIN CAPITAL LETTER I</td></tr><tr><td>Ⅷ</td><td>ROMAN NUMERAL EIGHT</td><td>VIII</td><td>LATIN CAPITAL LETTER V, LATIN CAPITAL LETTER I, LATIN CAPITAL LETTER I, LATIN CAPITAL LETTER I</td></tr><tr><td>Ⅸ</td><td>ROMAN NUMERAL NINE</td><td>IX</td><td>LATIN CAPITAL LETTER I, LATIN CAPITAL LETTER X</td></tr><tr><td>Ⅹ</td><td>ROMAN NUMERAL TEN</td><td>X</td><td>LATIN CAPITAL LETTER X</td></tr><tr><td>Ⅺ</td><td>ROMAN NUMERAL ELEVEN</td><td>XI</td><td>LATIN CAPITAL LETTER X, LATIN CAPITAL LETTER I</td></tr><tr><td>Ⅻ</td><td>ROMAN NUMERAL TWELVE</td><td>XII</td><td>LATIN CAPITAL LETTER X, LATIN CAPITAL LETTER I, LATIN CAPITAL LETTER I</td></tr><tr><td>Ⅼ</td><td>ROMAN NUMERAL FIFTY</td><td>L</td><td>LATIN CAPITAL LETTER L</td></tr><tr><td>Ⅽ</td><td>ROMAN NUMERAL ONE HUNDRED</td><td>C</td><td>LATIN CAPITAL LETTER C</td></tr><tr><td>Ⅾ</td><td>ROMAN NUMERAL FIVE HUNDRED</td><td>D</td><td>LATIN CAPITAL LETTER D</td></tr><tr><td>Ⅿ</td><td>ROMAN NUMERAL ONE THOUSAND</td><td>M</td><td>LATIN CAPITAL LETTER M</td></tr><tr><td>ⅰ</td><td>SMALL ROMAN NUMERAL ONE</td><td>i</td><td>LATIN SMALL LETTER I</td></tr><tr><td>ⅱ</td><td>SMALL ROMAN NUMERAL TWO</td><td>ii</td><td>LATIN SMALL LETTER I, LATIN SMALL LETTER I</td></tr><tr><td>ⅲ</td><td>SMALL ROMAN NUMERAL THREE</td><td>iii</td><td>LATIN SMALL LETTER I, LATIN SMALL LETTER I, LATIN SMALL LETTER I</td></tr><tr><td>ⅳ</td><td>SMALL ROMAN NUMERAL FOUR</td><td>iv</td><td>LATIN SMALL LETTER I, LATIN SMALL LETTER V</td></tr><tr><td>ⅴ</td><td>SMALL ROMAN NUMERAL FIVE</td><td>v</td><td>LATIN SMALL LETTER V</td></tr><tr><td>ⅵ</td><td>SMALL ROMAN NUMERAL SIX</td><td>vi</td><td>LATIN SMALL LETTER V, LATIN SMALL LETTER I</td></tr><tr><td>ⅶ</td><td>SMALL ROMAN NUMERAL SEVEN</td><td>vii</td><td>LATIN SMALL LETTER V, LATIN SMALL LETTER I, LATIN SMALL LETTER I</td></tr><tr><td>ⅷ</td><td>SMALL ROMAN NUMERAL EIGHT</td><td>viii</td><td>LATIN SMALL LETTER V, LATIN SMALL LETTER I, LATIN SMALL LETTER I, LATIN SMALL LETTER I</td></tr><tr><td>ⅸ</td><td>SMALL ROMAN NUMERAL NINE</td><td>ix</td><td>LATIN SMALL LETTER I, LATIN SMALL LETTER X</td></tr><tr><td>ⅹ</td><td>SMALL ROMAN NUMERAL TEN</td><td>x</td><td>LATIN SMALL LETTER X</td></tr><tr><td>ⅺ</td><td>SMALL ROMAN NUMERAL ELEVEN</td><td>xi</td><td>LATIN SMALL LETTER X, LATIN SMALL LETTER I</td></tr><tr><td>ⅻ</td><td>SMALL ROMAN NUMERAL TWELVE</td><td>xii</td><td>LATIN SMALL LETTER X, LATIN SMALL LETTER I, LATIN SMALL LETTER I</td></tr><tr><td>ⅼ</td><td>SMALL ROMAN NUMERAL FIFTY</td><td>l</td><td>LATIN SMALL LETTER L</td></tr><tr><td>ⅽ</td><td>SMALL ROMAN NUMERAL ONE HUNDRED</td><td>c</td><td>LATIN SMALL LETTER C</td></tr><tr><td>ⅾ</td><td>SMALL ROMAN NUMERAL FIVE HUNDRED</td><td>d</td><td>LATIN SMALL LETTER D</td></tr><tr><td>ⅿ</td><td>SMALL ROMAN NUMERAL ONE THOUSAND</td><td>m</td><td>LATIN SMALL LETTER M</td></tr><tr><td>ↀ</td><td>ROMAN NUMERAL ONE THOUSAND C D</td><td>ↀ</td><td>ROMAN NUMERAL ONE THOUSAND C D</td></tr><t ...

# %% [markdown]
# # Subscripts and superscripts
#
# There are a smattering of glyphs representing characters rendered in superscript or subscript.
#
# These normalize with the algorithm `NFKD` to their standard equivalents, but this would lose semantics in mathematical expressions: superscripts usually represent an exponent, and subscripts are used for indexing names.
#
# So make dictionaries of superscript and subscript characters, for the parser to use appropriately.
#
# In JME, a string of superscript characters produces a `^` operator token followed by whatever partial expression the normalized version corresponds to, wrapped in parentheses.
# For example, `x²⁺³` is equivalent to `x^(2+3)`.

# %%
subscript = [c for c in all_unicode if 'SUBSCRIPT' in unicodedata.name(c)]

@tsv_symbols(tmp_dir / 'unedited-subscripts.tsv')
@table
def subscript_things():
    for c in subscript:
        n = unicodedata.normalize('NFKD',c)
        names = ', '.join(unicodedata.name(c) for c in n)
        yield [c, unicodedata.name(c), n, names]
# Out:
# <div style="max-height: 15em; overflow-y:auto"><table><tr><td>ٖ</td><td>ARABIC SUBSCRIPT ALEF</td><td>ٖ</td><td>ARABIC SUBSCRIPT ALEF</td></tr><tr><td>ᵢ</td><td>LATIN SUBSCRIPT SMALL LETTER I</td><td>i</td><td>LATIN SMALL LETTER I</td></tr><tr><td>ᵣ</td><td>LATIN SUBSCRIPT SMALL LETTER R</td><td>r</td><td>LATIN SMALL LETTER R</td></tr><tr><td>ᵤ</td><td>LATIN SUBSCRIPT SMALL LETTER U</td><td>u</td><td>LATIN SMALL LETTER U</td></tr><tr><td>ᵥ</td><td>LATIN SUBSCRIPT SMALL LETTER V</td><td>v</td><td>LATIN SMALL LETTER V</td></tr><tr><td>ᵦ</td><td>GREEK SUBSCRIPT SMALL LETTER BETA</td><td>β</td><td>GREEK SMALL LETTER BETA</td></tr><tr><td>ᵧ</td><td>GREEK SUBSCRIPT SMALL LETTER GAMMA</td><td>γ</td><td>GREEK SMALL LETTER GAMMA</td></tr><tr><td>ᵨ</td><td>GREEK SUBSCRIPT SMALL LETTER RHO</td><td>ρ</td><td>GREEK SMALL LETTER RHO</td></tr><tr><td>ᵩ</td><td>GREEK SUBSCRIPT SMALL LETTER PHI</td><td>φ</td><td>GREEK SMALL LETTER PHI</td></tr><tr><td>ᵪ</td><td>GREEK SUBSCRIPT SMALL LETTER CHI</td><td>χ</td><td>GREEK SMALL LETTER CHI</td></tr><tr><td>₀</td><td>SUBSCRIPT ZERO</td><td>0</td><td>DIGIT ZERO</td></tr><tr><td>₁</td><td>SUBSCRIPT ONE</td><td>1</td><td>DIGIT ONE</td></tr><tr><td>₂</td><td>SUBSCRIPT TWO</td><td>2</td><td>DIGIT TWO</td></tr><tr><td>₃</td><td>SUBSCRIPT THREE</td><td>3</td><td>DIGIT THREE</td></tr><tr><td>₄</td><td>SUBSCRIPT FOUR</td><td>4</td><td>DIGIT FOUR</td></tr><tr><td>₅</td><td>SUBSCRIPT FIVE</td><td>5</td><td>DIGIT FIVE</td></tr><tr><td>₆</td><td>SUBSCRIPT SIX</td><td>6</td><td>DIGIT SIX</td></tr><tr><td>₇</td><td>SUBSCRIPT SEVEN</td><td>7</td><td>DIGIT SEVEN</td></tr><tr><td>₈</td><td>SUBSCRIPT EIGHT</td><td>8</td><td>DIGIT EIGHT</td></tr><tr><td>₉</td><td>SUBSCRIPT NINE</td><td>9</td><td>DIGIT NINE</td></tr><tr><td>₊</td><td>SUBSCRIPT PLUS SIGN</td><td>+</td><td>PLUS SIGN</td></tr><tr><td>₋</td><td>SUBSCRIPT MINUS</td><td>−</td><td>MINUS SIGN</td></tr><tr><td>₌</td><td>SUBSCRIPT EQUALS SIGN</td><td>=</td><td>EQUALS SIGN</td></tr><tr><td>₍</td><td>SUBSCRIPT LEFT PARENTHESIS</td><td>(</td><td>LEFT PARENTHESIS</td></tr><tr><td>₎</td><td>SUBSCRIPT RIGHT PARENTHESIS</td><td>)</td><td>RIGHT PARENTHESIS</td></tr><tr><td>ₐ</td><td>LATIN SUBSCRIPT SMALL LETTER A</td><td>a</td><td>LATIN SMALL LETTER A</td></tr><tr><td>ₑ</td><td>LATIN SUBSCRIPT SMALL LETTER E</td><td>e</td><td>LATIN SMALL LETTER E</td></tr><tr><td>ₒ</td><td>LATIN SUBSCRIPT SMALL LETTER O</td><td>o</td><td>LATIN SMALL LETTER O</td></tr><tr><td>ₓ</td><td>LATIN SUBSCRIPT SMALL LETTER X</td><td>x</td><td>LATIN SMALL LETTER X</td></tr><tr><td>ₔ</td><td>LATIN SUBSCRIPT SMALL LETTER SCHWA</td><td>ə</td><td>LATIN SMALL LETTER SCHWA</td></tr><tr><td>ₕ</td><td>LATIN SUBSCRIPT SMALL LETTER H</td><td>h</td><td>LATIN SMALL LETTER H</td></tr><tr><td>ₖ</td><td>LATIN SUBSCRIPT SMALL LETTER K</td><td>k</td><td>LATIN SMALL LETTER K</td></tr><tr><td>ₗ</td><td>LATIN SUBSCRIPT SMALL LETTER L</td><td>l</td><td>LATIN SMALL LETTER L</td></tr><tr><td>ₘ</td><td>LATIN SUBSCRIPT SMALL LETTER M</td><td>m</td><td>LATIN SMALL LETTER M</td></tr><tr><td>ₙ</td><td>LATIN SUBSCRIPT SMALL LETTER N</td><td>n</td><td>LATIN SMALL LETTER N</td></tr><tr><td>ₚ</td><td>LATIN SUBSCRIPT SMALL LETTER P</td><td>p</td><td>LATIN SMALL LETTER P</td></tr><tr><td>ₛ</td><td>LATIN SUBSCRIPT SMALL LETTER S</td><td>s</td><td>LATIN SMALL LETTER S</td></tr><tr><td>ₜ</td><td>LATIN SUBSCRIPT SMALL LETTER T</td><td>t</td><td>LATIN SMALL LETTER T</td></tr><tr><td>⨧</td><td>PLUS SIGN WITH SUBSCRIPT TWO</td><td>⨧</td><td>PLUS SIGN WITH SUBSCRIPT TWO</td></tr><tr><td>ⱼ</td><td>LATIN SUBSCRIPT SMALL LETTER J</td><td>j</td><td>LATIN SMALL LETTER J</td></tr></table></div>

# %%
subscript_mapping = {}

with open('subscripts.tsv') as f:
    for row in f.read().strip().split('\n'):
        bits = row.split('\t')
        c = bits[0]
        alias = bits[4]
        subscript_mapping[c] = [alias, []]
 
with open(output_dir / 'subscripts.json','w') as f:
    json.dump(subscript_mapping, f, indent=4)

# %%
superscript = [c for c in all_unicode if 'SUPERSCRIPT' in unicodedata.name(c)]

@tsv_symbols(tmp_dir / 'unedited-superscripts.tsv')
@table
def superscript_things():
    for c in superscript:
        n = unicodedata.normalize('NFKD',c)
        names = ', '.join(unicodedata.name(c) for c in n)
        yield [c, unicodedata.name(c), n, names]
# Out:
# <div style="max-height: 15em; overflow-y:auto"><table><tr><td>²</td><td>SUPERSCRIPT TWO</td><td>2</td><td>DIGIT TWO</td></tr><tr><td>³</td><td>SUPERSCRIPT THREE</td><td>3</td><td>DIGIT THREE</td></tr><tr><td>¹</td><td>SUPERSCRIPT ONE</td><td>1</td><td>DIGIT ONE</td></tr><tr><td>ٰ</td><td>ARABIC LETTER SUPERSCRIPT ALEF</td><td>ٰ</td><td>ARABIC LETTER SUPERSCRIPT ALEF</td></tr><tr><td>ܑ</td><td>SYRIAC LETTER SUPERSCRIPT ALAPH</td><td>ܑ</td><td>SYRIAC LETTER SUPERSCRIPT ALAPH</td></tr><tr><td>⁰</td><td>SUPERSCRIPT ZERO</td><td>0</td><td>DIGIT ZERO</td></tr><tr><td>ⁱ</td><td>SUPERSCRIPT LATIN SMALL LETTER I</td><td>i</td><td>LATIN SMALL LETTER I</td></tr><tr><td>⁴</td><td>SUPERSCRIPT FOUR</td><td>4</td><td>DIGIT FOUR</td></tr><tr><td>⁵</td><td>SUPERSCRIPT FIVE</td><td>5</td><td>DIGIT FIVE</td></tr><tr><td>⁶</td><td>SUPERSCRIPT SIX</td><td>6</td><td>DIGIT SIX</td></tr><tr><td>⁷</td><td>SUPERSCRIPT SEVEN</td><td>7</td><td>DIGIT SEVEN</td></tr><tr><td>⁸</td><td>SUPERSCRIPT EIGHT</td><td>8</td><td>DIGIT EIGHT</td></tr><tr><td>⁹</td><td>SUPERSCRIPT NINE</td><td>9</td><td>DIGIT NINE</td></tr><tr><td>⁺</td><td>SUPERSCRIPT PLUS SIGN</td><td>+</td><td>PLUS SIGN</td></tr><tr><td>⁻</td><td>SUPERSCRIPT MINUS</td><td>−</td><td>MINUS SIGN</td></tr><tr><td>⁼</td><td>SUPERSCRIPT EQUALS SIGN</td><td>=</td><td>EQUALS SIGN</td></tr><tr><td>⁽</td><td>SUPERSCRIPT LEFT PARENTHESIS</td><td>(</td><td>LEFT PARENTHESIS</td></tr><tr><td>⁾</td><td>SUPERSCRIPT RIGHT PARENTHESIS</td><td>)</td><td>RIGHT PARENTHESIS</td></tr><tr><td>ⁿ</td><td>SUPERSCRIPT LATIN SMALL LETTER N</td><td>n</td><td>LATIN SMALL LETTER N</td></tr><tr><td>ﱛ</td><td>ARABIC LIGATURE THAL WITH SUPERSCRIPT ALEF ISOLATED FORM</td><td>ذٰ</td><td>ARABIC LETTER THAL, ARABIC LETTER SUPERSCRIPT ALEF</td></tr><tr><td>ﱜ</td><td>ARABIC LIGATURE REH WITH SUPERSCRIPT ALEF ISOLATED FORM</td><td>رٰ</td><td>ARABIC LETTER REH, ARABIC LETTER SUPERSCRIPT ALEF</td></tr><tr><td>ﱝ</td><td>ARABIC LIGATURE ALEF MAKSURA WITH SUPERSCRIPT ALEF ISOLATED FORM</td><td>ىٰ</td><td>ARABIC LETTER ALEF MAKSURA, ARABIC LETTER SUPERSCRIPT ALEF</td></tr><tr><td>ﱣ</td><td>ARABIC LIGATURE SHADDA WITH SUPERSCRIPT ALEF ISOLATED FORM</td><td> ّٰ</td><td>SPACE, ARABIC SHADDA, ARABIC LETTER SUPERSCRIPT ALEF</td></tr><tr><td>ﲐ</td><td>ARABIC LIGATURE ALEF MAKSURA WITH SUPERSCRIPT ALEF FINAL FORM</td><td>ىٰ</td><td>ARABIC LETTER ALEF MAKSURA, ARABIC LETTER SUPERSCRIPT ALEF</td></tr><tr><td>ﳙ</td><td>ARABIC LIGATURE HEH WITH SUPERSCRIPT ALEF INITIAL FORM</td><td>هٰ</td><td>ARABIC LETTER HEH, ARABIC LETTER SUPERSCRIPT ALEF</td></tr></table></div>

# %%
superscript_mapping = {}

with open('superscripts.tsv') as f:
    for row in f.read().strip().split('\n'):
        bits = row.split('\t')
        c = bits[0]
        alias = bits[4]
        superscript_mapping[c] = [alias, []]
 
with open(output_dir / 'superscripts.json','w') as f:
    json.dump(superscript_mapping, f, indent=4)

# %% [markdown]
# # Symbols from autolatex
# The file `autolatex-data.json` contains thousands of mappings from LaTeX math-mode commands to unicode characters.
# Let's find out which symbols in there haven't already been dealt with.

# %%
with open('autolatex-data.json') as f:
    d = json.load(f)
    autolatex_symbols = [y for x,y in d]

# %%
unmapped_autolatex = [c for c in sorted(set(autolatex_symbols)) if c not in symbol_mapping and c not in letter_mapping and c not in characters]

@tsv_symbols(tmp_dir / 'autolatex.tsv')
@table
def autolatex_todo():
    for c in unmapped_autolatex:
        if len(c)>1:
            continue
        try:
            cnames = ', '.join(unicodedata.name(x) for x in c)
            n = unicodedata.normalize('NFKD',c)
            nnames = ', '.join(unicodedata.name(c) for c in n)
            yield [len(c),c, unicodedata.category(c[0]), cnames, n, nnames]
        except ValueError:
            print("oops",c)
# Out:
# oops 
# <div style="max-height: 15em; overflow-y:auto"><table><tr><td>1</td><td>$</td><td>Sc</td><td>DOLLAR SIGN</td><td>$</td><td>DOLLAR SIGN</td></tr><tr><td>1</td><td>%</td><td>Po</td><td>PERCENT SIGN</td><td>%</td><td>PERCENT SIGN</td></tr><tr><td>1</td><td>@</td><td>Po</td><td>COMMERCIAL AT</td><td>@</td><td>COMMERCIAL AT</td></tr><tr><td>1</td><td>A</td><td>Lu</td><td>LATIN CAPITAL LETTER A</td><td>A</td><td>LATIN CAPITAL LETTER A</td></tr><tr><td>1</td><td>B</td><td>Lu</td><td>LATIN CAPITAL LETTER B</td><td>B</td><td>LATIN CAPITAL LETTER B</td></tr><tr><td>1</td><td>C</td><td>Lu</td><td>LATIN CAPITAL LETTER C</td><td>C</td><td>LATIN CAPITAL LETTER C</td></tr><tr><td>1</td><td>D</td><td>Lu</td><td>LATIN CAPITAL LETTER D</td><td>D</td><td>LATIN CAPITAL LETTER D</td></tr><tr><td>1</td><td>E</td><td>Lu</td><td>LATIN CAPITAL LETTER E</td><td>E</td><td>LATIN CAPITAL LETTER E</td></tr><tr><td>1</td><td>F</td><td>Lu</td><td>LATIN CAPITAL LETTER F</td><td>F</td><td>LATIN CAPITAL LETTER F</td></tr><tr><td>1</td><td>G</td><td>Lu</td><td>LATIN CAPITAL LETTER G</td><td>G</td><td>LATIN CAPITAL LETTER G</td></tr><tr><td>1</td><td>H</td><td>Lu</td><td>LATIN CAPITAL LETTER H</td><td>H</td><td>LATIN CAPITAL LETTER H</td></tr><tr><td>1</td><td>I</td><td>Lu</td><td>LATIN CAPITAL LETTER I</td><td>I</td><td>LATIN CAPITAL LETTER I</td></tr><tr><td>1</td><td>J</td><td>Lu</td><td>LATIN CAPITAL LETTER J</td><td>J</td><td>LATIN CAPITAL LETTER J</td></tr><tr><td>1</td><td>K</td><td>Lu</td><td>LATIN CAPITAL LETTER K</td><td>K</td><td>LATIN CAPITAL LETTER K</td></tr><tr><td>1</td><td>L</td><td>Lu</td><td>LATIN CAPITAL LETTER L</td><td>L</td><td>LATIN CAPITAL LETTER L</td></tr><tr><td>1</td><td>M</td><td>Lu</td><td>LATIN CAPITAL LETTER M</td><td>M</td><td>LATIN CAPITAL LETTER M</td></tr><tr><td>1</td><td>N</td><td>Lu</td><td>LATIN CAPITAL LETTER N</td><td>N</td><td>LATIN CAPITAL LETTER N</td></tr><tr><td>1</td><td>O</td><td>Lu</td><td>LATIN CAPITAL LETTER O</td><td>O</td><td>LATIN CAPITAL LETTER O</td></tr><tr><td>1</td><td>P</td><td>Lu</td><td>LATIN CAPITAL LETTER P</td><td>P</td><td>LATIN CAPITAL LETTER P</td></tr><tr><td>1</td><td>Q</td><td>Lu</td><td>LATIN CAPITAL LETTER Q</td><td>Q</td><td>LATIN CAPITAL LETTER Q</td></tr><tr><td>1</td><td>R</td><td>Lu</td><td>LATIN CAPITAL LETTER R</td><td>R</td><td>LATIN CAPITAL LETTER R</td></tr><tr><td>1</td><td>S</td><td>Lu</td><td>LATIN CAPITAL LETTER S</td><td>S</td><td>LATIN CAPITAL LETTER S</td></tr><tr><td>1</td><td>T</td><td>Lu</td><td>LATIN CAPITAL LETTER T</td><td>T</td><td>LATIN CAPITAL LETTER T</td></tr><tr><td>1</td><td>U</td><td>Lu</td><td>LATIN CAPITAL LETTER U</td><td>U</td><td>LATIN CAPITAL LETTER U</td></tr><tr><td>1</td><td>V</td><td>Lu</td><td>LATIN CAPITAL LETTER V</td><td>V</td><td>LATIN CAPITAL LETTER V</td></tr><tr><td>1</td><td>W</td><td>Lu</td><td>LATIN CAPITAL LETTER W</td><td>W</td><td>LATIN CAPITAL LETTER W</td></tr><tr><td>1</td><td>X</td><td>Lu</td><td>LATIN CAPITAL LETTER X</td><td>X</td><td>LATIN CAPITAL LETTER X</td></tr><tr><td>1</td><td>Y</td><td>Lu</td><td>LATIN CAPITAL LETTER Y</td><td>Y</td><td>LATIN CAPITAL LETTER Y</td></tr><tr><td>1</td><td>Z</td><td>Lu</td><td>LATIN CAPITAL LETTER Z</td><td>Z</td><td>LATIN CAPITAL LETTER Z</td></tr><tr><td>1</td><td>_</td><td>Pc</td><td>LOW LINE</td><td>_</td><td>LOW LINE</td></tr><tr><td>1</td><td>`</td><td>Sk</td><td>GRAVE ACCENT</td><td>`</td><td>GRAVE ACCENT</td></tr><tr><td>1</td><td>a</td><td>Ll</td><td>LATIN SMALL LETTER A</td><td>a</td><td>LATIN SMALL LETTER A</td></tr><tr><td>1</td><td>b</td><td>Ll</td><td>LATIN SMALL LETTER B</td><td>b</td><td>LATIN SMALL LETTER B</td></tr><tr><td>1</td><td>c</td><td>Ll</td><td>LATIN SMALL LETTER C</td><td>c</td><td>LATIN SMALL LETTER C</td></tr><tr><td>1</td><td>d</td><td>Ll</td><td>LATIN SMALL LETTER D</td><td>d</td><td>LATIN SMALL LETTER D</td></tr><tr><td>1</td><td>e</td><td>Ll</td><td>LATIN SMALL LETTER E</td><td>e</td><td>LATIN SMALL LETTER E</td></tr><tr><td>1</td><td>f</td><td>Ll</td><td>LAT ...
# oops 

# %% [markdown]
# To deal with:
#
# * Vulgar fraction characters, such as `¼ ½ ¾`. These might be combined with a string of digits to represent a fractional quantity, e.g. 13¾, "thirteen and three quarters".
# * Some double-struck, script and black-letter characters: I've put these in `other-letters.tsv`.
# * Some characters representing physical constants, e.g. ℎ, `PLANCK CONSTANT`, also in `other-letters.tsv`.
# * Punctuation characters: primes, doubled and tripled exclamation and question marks.
# * Ceiling and floor delimiters, and angle brackets: `⌈ ⌉ ⌊ ⌋ 〈 〉`. These need to be dealt with in the parser.
